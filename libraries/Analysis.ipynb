# %%
import pandas as pd

# %% [markdown]
# - creating dataset
#   - dictionary of items
#   - list of items
#   - importing csv files
#   - importing excel files
#   - importing json files
# - reading data
# - selection of data
# - cleaning the data
# - visualizing the data
# - saving the data

# %%
movies = {
    'title': ['pushpa', 'kgf', 'rrr', 'pk', 'sahoo', 'chhava'],
    'rating': [4.5, 4.9, 4.6, 4.3, 4.8, 4.1],
    'year': [2021, 2018, 2020, 2019, 2022, 2021]
}
pd.DataFrame(movies)
# Out:
#     title  rating  year
# 0  pushpa     4.5  2021
# 1     kgf     4.9  2018
# 2     rrr     4.6  2020
# 3      pk     4.3  2019
# 4   sahoo     4.8  2022
# 5  chhava     4.1  2021

# %%
books = [
    {'title': 'harry potter', 'rating': 4.5, 'year': 2004},
    {'title': 'lord of the rings', 'rating': 4.3, 'year': 2008},
    {'title': 'autobiography of a yogi', 'rating': 4.8, 'year': 2012},
    {'title': 'atomic habits', 'rating': 4.4, 'year': 2010},
    {'title': 'moonwalking with einstein', 'rating': 4.2, 'year': 1997},
]
pd.DataFrame(books)
# Out:
#                        title  rating  year
# 0               harry potter     4.5  2004
# 1          lord of the rings     4.3  2008
# 2    autobiography of a yogi     4.8  2012
# 3              atomic habits     4.4  2010
# 4  moonwalking with einstein     4.2  1997

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(25)
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.tail(15)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21598  8956200760  20141013T000000   541800.0         4       2.50
# 21599  7202300110  20140915T000000   810000.0         4       3.00
# 21600   249000205  20141015T000000  1537000.0         5       3.75
# 21601  5100403806  20150407T000000   467000.0         3       2.50
# 21602   844000965  20140626T000000   224000.0         3       1.75
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe(include='object')
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.rename(columns={'price': 'money'})
# Out:
#                id             date     money  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# Row wise selection
# - iloc - index based location
# - loc - label based location

# %%
df.iloc[0]
# Out:
# id                    7129300520
# date             20141013T000000
# price                   221900.0
# bedrooms                       3
# bathrooms                    1.0
# sqft_living                 1180
# sqft_lot                    5650
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1180
# sqft_basement                  0
# yr_built                    1955
# yr_renovated                   0
# zipcode                    98178
# lat                      47.5112
# long                    -122.257
# sqft_living15               1340
# sqft_lot15                  5650
# Name: 0, dtype: object

# %%
df.iloc[10: 21]
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 10  1736800520  20150403T000000  662500.0         3       2.50         3560
# 11  9212900260  20140527T000000  468000.0         2       1.00         1160
# 12   114101516  20140528T000000  310000.0         3       1.00         1430
# 13  6054650070  20141007T000000  400000.0         3       1.75         1370
# 14  1175000570  20150312T000000  530000.0         5       2.00         1810
# 15  9297300055  20150124T000000  650000.0         4       3.00         2950
# 16  1875500060  20140731T000000  395000.0         3       2.00         1890
# 17  6865200140  20140529T000000  485000.0         4       1.00         1600
# 18    16000397  20141205T000000  189000.0         2       1.00         1200
# 19  7983200060  20150424T000000  230000.0         3       1.00         1250
# 20  6300500875  20140514T000000  385000.0         4       1.75         1620
#
# ...

# %%
df.iloc[[3, 5, 6, 7, 8, 11]]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 11  9212900260  20140527T000000   468000.0         2       1.00         1160
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3       5000     1.0           0     0  ...      7        1050            910
# 5     101930     1.0           0     0  ...     11        3890           1530
# 6       6819     2.0           0     0  ...      7        1715              0
# 7       9711     1.0           0     0  ...      7        1060              0
# ...

# %%
df.iloc[[3, 4, 6, 7], [0, 1, 2, 3]]
# Out:
#            id             date     price  bedrooms
# 3  2487200875  20141209T000000  604000.0         4
# 4  1954400510  20150218T000000  510000.0         3
# 6  1321400060  20140627T000000  257500.0         3
# 7  2008000270  20150115T000000  291850.0         3

# %%
df = df.set_index('id')
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
# condition is that the label we are using must be a primary key
df.loc[2487200875]
# Out:
# date             20141209T000000
# price                   604000.0
# bedrooms                       4
# bathrooms                    3.0
# sqft_living                 1960
# sqft_lot                    5000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      5
# grade                          7
# sqft_above                  1050
# sqft_basement                910
# yr_built                    1965
# yr_renovated                   0
# zipcode                    98136
# lat                      47.5208
# long                    -122.393
# sqft_living15               1360
# sqft_lot15                  5000
# Name: 2487200875, dtype: object

# %%
df.loc[[2487200875, 6414100192]]
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 6414100192  20141209T000000  538000.0         3       2.25         2570
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 2487200875      5000     1.0           0     0          5      7        1050
# 6414100192      7242     2.0           0     0          3      7        2170
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 6414100192            400      1951          1991    98125  47.7210 -122.319
#
#             sqft_living15  sqft_lot15
# id
# 2487200875           1360        5000
# 6414100192           1690        7639

# %%
df.read_csv('kc_house_data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.read_csv('kc_house_data.csv')
#       2 df
#
# NameError: name 'df' is not defined
